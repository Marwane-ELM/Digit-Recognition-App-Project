# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, KFold, learning_curve
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import confusion_matrix
from skopt import BayesSearchCV

import os
from joblib import dump, load

# %% [markdown]
# ## Import du dataset

# %%
mnist = np.load("../data/mnist_prepared.npz")

# %%
X = mnist["X"]
Y = mnist["Y"]

# %% [markdown]
# ### Train_test_split

# %%
def persistent_train_test_split(x, y, path, train_size):

    t_size = str(train_size).replace('.', '_')
    file_name = "MNIST_data_split" + '_' + t_size
    path_train_size = path + file_name
    
    if os.path.isfile(path_train_size):
        X_train, X_test, Y_train, Y_test = load(path_train_size)
        print("Le split a été importé avec succès")
    else :         
        X_train, X_test, Y_train, Y_test = train_test_split(
            x,
            y,
            train_size = train_size,   # On entraine sur 5% de notre dataset
            stratify = y,
            shuffle = True,
            random_state = 42
        )
        
        dump((X_train, X_test, Y_train, Y_test), path_train_size)
        print("Le split a été créé et importé avec succès")

    return X_train, X_test, Y_train, Y_test

# %%
MNB_path_data = "../data/"

X_train, X_test, Y_train, Y_test = persistent_train_test_split(X, Y, MNB_path_data, 0.05)
# Out:
# Le split a été importé avec succès

# %%
X_train.shape
# Out:
# (3500, 784)

# %% [markdown]
# ## Multinomial Naive Bayes model

# %%
MNB = MultinomialNB()
# Out:
# [CV 3/3] END alpha=0.052992263829421286, binarize=1;, score=0.854 total time=   0.1s
# [CV 2/3] END alpha=86.29431902910807, binarize=101;, score=0.620 total time=   0.1s
# [CV 3/3] END alpha=0.32298186468495127, binarize=101;, score=0.851 total time=   0.1s
# [CV 1/3] END alpha=5.384474695013668, binarize=151;, score=0.807 total time=   0.1s
# [CV 1/3] END alpha=0.0011934768265107643, binarize=1;, score=0.838 total time=   0.1s

# %% [markdown]
# ##### Fonction de sauvegarde de modèles entraînés

# %%
def dump_artefact(tuned_model, path_artefact : str, artefact_name : str):

    
    score = round(tuned_model.best_score_, 3)  # on arrondis le score à 3 décimales
    score = str(score).replace('.', '')
    name = artefact_name + '_' + score

    path = path_artefact + name
    if os.path.isfile(path):
        print(f"Le modèle {artefact_name} existe déjà")

    else :
        model = dump(tuned_model.best_estimator_, path)  # Si le modèle a déjà été crée précédemment, alors on l'importe
        print(f"L'artefact de {artefact_name} a été crée avec succès")

# %% [markdown]
# #### Recherche d'hyperparamètres n°1

# %%
param_grid_MNB1 = {
    'alpha' : np.abs(np.random.lognormal(0, 10, 300))
}

# %%
Grid_MNB1 = BayesSearchCV(
    estimator = MNB,
    search_spaces = param_grid_MNB1,
    n_iter = 20,
    scoring = 'accuracy',
    cv = KFold(n_splits = 4),
    verbose = 4,
    n_jobs = 10
)

# %%
Grid_MNB1.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# BayesSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=False),
#               estimator=MultinomialNB(), n_iter=20, n_jobs=10,
#               scoring='accuracy',
#               search_spaces={'alpha': array([3.79636140e-10, 1.18158661e+01, 2.14084955e+07, 1.61198916e+02,
#        1.34192187e+05, 8.50299261e-11, 5.58881008e-07, 1.71714174e-01,
#        5.70746756e-09, 2.52717104e-07, 9.19430290e+01, 1.45356451e-01,
#        1.738886...
#        1.00541559e+04, 1.71566960e-01, 2.22959435e-09, 8.30661562e+01,
#        5.48286603e-02, 6.48350202e-06, 2.25078577e-05, 1.91124925e-05,
#        1.72785109e-07, 1.12922149e+00, 2.38541166e+08, 3.11605196e+02,
#        1.06724379e+04, 5.99615900e+03, 4.52054228e+02, 1.64603941e+05,
#        7.87130578e-06, 1.57979623e-04, 7.58702057e-06, 5.52043205e+04,
#        2.47092839e-03, 1.55391724e-09, 1.63168316e-02, 3.79795319e-03])},
#               verbose=4)

# %%
print("Best params : ", Grid_MNB1.best_params_ )
print("Best score : ", Grid_MNB1.best_score_)
# Out:
# Best params :  OrderedDict({'alpha': 0.26572569475470204})
# Best score :  0.8265714285714285

# %%
dump_artefact(
    tuned_model = Grid_MNB1,
    path_artefact = "../saved_models/MultinomialNB_persistent/",
    artefact_name = "MNB1"
)
# Out:
# L'artefact de MNB1 a été crée avec succès

# %% [markdown]
# #### Recherche d'hyperparamètres n°2

# %%
param_grid_MNB2 = {
    'alpha' : np.abs(np.random.lognormal(0.265, 10, 300))
}

# %%
Grid_MNB2 = BayesSearchCV(
    estimator = MNB,
    search_spaces = param_grid_MNB2,
    n_iter = 20,
    scoring = 'accuracy',
    cv = KFold(n_splits = 4),
    verbose = 4,
    n_jobs = 10
)

# %%
Grid_MNB2.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# BayesSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=False),
#               estimator=MultinomialNB(), n_iter=20, n_jobs=10,
#               scoring='accuracy',
#               search_spaces={'alpha': array([2.04386816e+00, 8.68191171e+03, 3.40094711e+02, 3.67959391e+02,
#        3.65029280e-02, 7.98651172e-01, 6.49033166e-04, 5.05435195e-01,
#        2.79699945e+02, 3.79705895e+04, 2.52196558e-05, 1.58446027e+01,
#        2.187056...
#        5.55064037e-03, 6.47639849e+02, 5.31300331e-03, 2.21548227e-07,
#        4.95960524e+00, 3.65605955e+00, 3.55126746e-04, 1.47425693e-03,
#        3.53322560e+04, 1.13181669e+00, 7.90292694e+01, 4.65622091e-03,
#        6.51159557e-06, 5.65932905e+03, 2.92726255e+02, 9.18164453e+01,
#        1.51572526e+00, 1.24152847e+05, 3.48750038e+06, 3.89605868e+04,
#        2.57145260e+02, 2.20873275e-05, 4.33366426e-12, 1.83348957e-01])},
#               verbose=4)

# %%
print("Best params : ", Grid_MNB2.best_params_ )
print("Best score : ", Grid_MNB2.best_score_)
# Out:
# Best params :  OrderedDict({'alpha': 0.00531300330897422})
# Best score :  0.8268571428571428

# %%
dump_artefact(
    tuned_model = Grid_MNB2,
    path_artefact = "../saved_models/MultinomialNB_persistent/",
    artefact_name = "MNB2"
)
# Out:
# L'artefact de MNB2 a été crée avec succès

# %% [markdown]
# #### Recherche d'hyperparamètres n°3

# %%
param_grid_MNB3 = {
    'alpha' : np.abs(np.random.lognormal(0, 1, 100))
}

# %%
Grid_MNB3 = BayesSearchCV(
    estimator = MNB,
    search_spaces = param_grid_MNB3,
    n_iter = 20,
    scoring = 'accuracy',
    cv = KFold(n_splits = 4),
    verbose = 4,
    n_jobs = 10
)

# %%
Grid_MNB3.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# BayesSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=False),
#               estimator=MultinomialNB(), n_iter=20, n_jobs=10,
#               scoring='accuracy',
#               search_spaces={'alpha': array([ 0.53008598,  1.71825497,  0.43535027,  0.92735795,  1.7351651 ,
#         3.1930586 ,  4.38711135,  0.54076865,  0.55512781,  2.35139235,
#         2.1297683 , 11.43213647,  1.32086003,  0.80641497,  1.73720842,
#         0.75323506,  0.68109494,  2.1...
#         0.48233293,  1.24325055,  1.59234042,  1.71425361,  0.50294406,
#         0.41441447,  1.59581436,  1.00822389,  0.11349018,  0.94985888,
#         1.59404535,  0.31726717,  0.14228896,  1.39733573,  1.07021896,
#         0.94226082,  2.02921519,  1.736542  ,  1.24929699,  0.41548282,
#         0.59270636,  1.23646397,  1.82551563,  0.8859702 ,  0.42300768,
#         1.03623096,  0.35185238,  1.53407507,  2.60714979,  0.65931637,
#         0.36172958,  0.76616396,  0.11959041,  0.22424504,  4.44999165])},
#               verbose=4)

# %%
print("Best params : ", Grid_MNB3.best_params_ )
print("Best score : ", Grid_MNB3.best_score_)
# Out:
# Best params :  OrderedDict({'alpha': 0.46323183820693004})
# Best score :  0.8265714285714286

# %%
dump_artefact(
    tuned_model = Grid_MNB3,
    path_artefact = "../saved_models/MultinomialNB_persistent/",
    artefact_name = "MNB3"
)
# Out:
# L'artefact de MNB3 a été crée avec succès

# %% [markdown]
# #### Recherche d'hyperparamètres n°4

# %%
param_grid_MNB4 = {
    'alpha' : np.abs(np.random.normal(5, 20, 300))
}

# %%
Grid_MNB4 = BayesSearchCV(
    estimator = MNB,
    search_spaces = param_grid_MNB4,
    n_iter = 20,
    scoring = 'accuracy',
    cv = KFold(n_splits = 4),
    verbose = 4,
    n_jobs = 10
)

# %%
Grid_MNB4.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# BayesSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=False),
#               estimator=MultinomialNB(), n_iter=20, n_jobs=10,
#               scoring='accuracy',
#               search_spaces={'alpha': array([9.70629967e+00, 1.03863131e+01, 2.09233633e+01, 4.48215383e+00,
#        1.11695237e+01, 4.46802996e+00, 6.90404644e+00, 6.41162102e+00,
#        1.03940259e+01, 1.72933430e+00, 1.49319402e+01, 5.31882219e+00,
#        1.950298...
#        4.22704132e+00, 1.14405278e+01, 1.77373307e+01, 1.57537162e+01,
#        9.76939354e+00, 1.29703624e+01, 1.57916768e+01, 2.88160153e+00,
#        1.38541874e+01, 2.24007298e+01, 5.35454819e+00, 1.31281100e-01,
#        7.24905590e+00, 6.11027582e+00, 1.20581549e+01, 9.56054248e-01,
#        2.62629865e+01, 3.47885552e+00, 1.21440346e+01, 2.53986448e+00,
# [CV 1/4] END ...........alpha=3.999176296367949;, score=0.835 total time=   0.1s
# [CV 3/4] END ...........alpha=4.120725853461043;, score=0.829 total time=   0.1s
# [CV 2/4] END ..........alpha=16.582995131480647;, score=0.803 total time=   0.1s
# [CV 3/4] END ..........alpha=25.880635285428994;, score=0.825 total time=   0.1s
# [CV 2/4] END ..........alpha=18.486806970620854;, score=0.803 total time=   0.1s
# [CV 3/4] END ..........alpha=19.437083072855664;, score=0.825 total time=   0.1s
# [CV 3/4] END ..........alpha=3.9019853072369077;, score=0.829 total time=   0.1s
# [CV 2/4] END ...........alpha=1.112786190533141;, score=0.803 total time=   0.1s
# [CV 2/4] END ...........alpha=9.515928327590203;, score=0.802 total time=   0.1s
# [CV 3/4] END ...........alpha=4.803836290497735;, score=0.829 total time=   0.1s
# [CV 2/4] END ...........alpha=4.120725853461043;, score=0.803 total time=   0.1s

# %% [markdown]
# #### Train Score & Test_score

# %%
def best_model(path):
    biggest_score = 0
    best_model = ""
    for artefact_name in os.listdir(path):
        if artefact_name != ".ipynb_checkpoints":
            score = int(artefact_name[-4:])
            if score > biggest_score:
                biggest_score = score
                best_model = artefact_name
    path_best_model = path + best_model
    model = load(path_best_model)
    return model

# %%
Best_model = best_model("../saved_models/MultinomialNB_persistent/")

# %%
print("Train_set score : ", Best_model.score(X_train, Y_train))
print("Test_set score : ", Best_model.score(X_test, Y_test))
# Out:
# Train_set score :  0.8394285714285714
# Test_set score :  0.8294436090225564

# %% [markdown]
# Le score est très proche donc c'est un signe que notre modèle n'est ni en underfitting, ni en overfitting.
# Il est juste bon, ni plus ni moins.

# %% [markdown]
# #### Learning Curve

# %%
N, train_scores, val_scores = learning_curve(Best_model, X_train, Y_train, train_sizes=np.linspace(0.1, 1, 40))

# %%
plt.figure(figsize=(5, 4))
plt.plot(N, train_scores.mean(axis=1), c='blue', label="train_score")
plt.plot(N, val_scores.mean(axis=1), c='orange', label="val_score")
plt.legend()

# %%
predictions = Best_model.predict(X_test)
confusion_matrix = confusion_matrix(predictions, Y_test)

# %%
heatmap = sns.heatmap(confusion_matrix, annot=True, fmt='.0f', cmap="cividis", linewidths=0.5)
heatmap.set(xlabel="Predictions", ylabel="True values")
# Out:
# [Text(0.5, 23.52222222222222, 'Predictions'),
#  Text(50.722222222222214, 0.5, 'True values')]

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Le modèle est globalement correct.
# En effet, malgré une baisse de "l'accuracy" sur le jeu d'entraînement, au fur et à mesure que les données d'entraînement augmentent, on constate que l'écart diminue entre le score du training set et celui du validation set.
# On en conclue que le modèle n'a pas besoin de plus de données pour l'entraînement car les scores sur le training_set et le val_det convergent autour de 83% d'accuracy.
# De plus, le modèle capture assez bien les liens entre nos données en entrées et leur vraie valeur. Le modèle est Bayésien et naïf, donc il suppose une indépendance entre les features, ce qui n'est pas le cas, d'où un score inférieur à 90%
# Peut-être qu'avec un meilleur traitement des données (Réduction de dimension, modification des valeurs des pixels des images etc...) on pourrait avoir un meilleur score.
